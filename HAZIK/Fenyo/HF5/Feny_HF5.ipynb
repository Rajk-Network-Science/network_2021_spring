# %%
# %run Feny_HF5.py

# %%
subG = read_data_create_graph()
# Out:
# Data read successfully.
#
#
# Graph created successfully.
#
# The number of nodes is:  1632803
# The number of edges is:  22301964
# The average degree is:  27.31739713854029
# Successfully created subgraph
#
# The number of nodes is:  46325
# The number of edges is:  342522
# The average degree is:  14.787781975175392
# Dropped garbage.

# %% [markdown]
# A fentiekben az eredeti, több, mint másfél millió csúcsú hálózatból vettem egy mintát aszerint, hogy az adott élnek valamelyik csúcsa ***nitriansky kraj, nitra*** régióhoz tartozik-e.
#
# Láthatjuk, hogy az átlagos fokszám, és a fokszámeloszlás eltér a teljes hálózatétól, viszont így is sokkal jobb eredményt kapunk, mint Random Walk, Snowball, vagy a régióhoz tartozó csúcsokra történő leszűréskor. (Mindezek a szűrési módszerek 1-3 közötti átlagos fokszámot eredményeztek.)

# %%
make_plots(subG)

# %%
make_heatmaps(subG)

# %%
base_gender_model(subG)
# Out:
# A nemi megoszlás a hálózatban:
# female    23535
# male      22790
# dtype: int64
#
#
# A nemi megoszlás a becslés alapján:
# female    24750
# male      21575
# dtype: int64
#
#
# A helyesen címkézett személyek aránya: 0.499
