# %%
# %run Feny_HF4.py

# %%
ERcomp, ERlog, link, log1, copy, log2, ba, log3 = create_graphs(1000)
# Out:
# The chosen number of additional nodes to base 20 is  1000
# Created comparison info of ER graph
# Created graph with link selection
# Created graph with copy model
# Created graph with BA model

# %%
visualize_graphs(ERcomp, ERlog, link, log1, copy, log2, ba, log3)

# %% [markdown]
# A fenti ábrákon látszik, hogy a létrehozott hálózatokban csomópontok alakultak ki, és ezek nagy eséllyel lettek az eredeti hálózat csúcsai, vagy az azokhoz korábban csatlakozó csúcsok. (A kék csúcsok az eredeti 20 csúcsú ER gráf csúcsai.)

# %%
avg_clustering_plot(ERcomp, ERlog, link, log1, copy, log2, ba, log3)

# %% [markdown]
# A fenti ábra bemutatja, hogy a három különböző algoritmussal létrehozott hálózat skálafüggetlen. Referenciaként láthatjuk az adott méretű ER gráf (véletlen gráf) átlagos klaszterezettségi együtthatóját.
