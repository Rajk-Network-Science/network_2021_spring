# %% [markdown]
# **Import Functions and Data**

# %%
# %run Feny_HF3.py

# %%
analyse(generate_graph(PATH))
# Out:
# Successfully read graph from  ../HF3/lasftm_asia/lastfm_asia_edges.csv
# Number of nodes:  7624
# Number of edges:  27806
#
#
# The average degree in the graph is:  7.2943336831059815
# Calculating this took 0.0046 seconds
#
#
# Diameter of network:  15
# Calculating this took 92.1740 seconds
#
#
# Average eccentricity:  10.457240293809024
# Calculating this took 91.3623 seconds
#
#
# Average Clustering Coefficient:  0.2194184243270858
# Calculating this took 0.2838 seconds
# Ended full analysis in 347.3475 seconds
