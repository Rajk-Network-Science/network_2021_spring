# %%
from hazi_3 import deskriptiv
from hazi_3 import graph_objektum
from hazi_3 import fokszam
from hazi_3 import fokszameloszlas

# %%
G=graph_objektum("lastfm_asia_edges.csv")
fokszameloszlas(fokszam(G))

# %%
deskriptiv(G)
# Out:
# Number of nodes: 7624
# Number of egdes: 27806
# Average degree: 7.2943336831059815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e2ff64874723> in <module>
# ----> 1 deskriptiv(G)
#
# ~\Documents\NetworkScience\network_2021_spring\network_2021_spring\HAZIK\Hobot\hazi_3.py in deskriptiv(G)
#      13     print("Number of egdes:", G.number_of_edges() )
#      14     print("Average degree:",2*len(G.edges)/len(G.nodes))
# ---> 15     print("Diameter:", nx.diameter(G))
#      16     print("Average shortest path", nx.average_shortest_path_length(G))
#      17
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in diameter(G, e, usebounds)
#     279         return extrema_bounding(G, compute="diameter")
#     280     if e is None:
# --> 281         e = eccentricity(G)
#     282     return max(e.values())
#     283
#
# ...
