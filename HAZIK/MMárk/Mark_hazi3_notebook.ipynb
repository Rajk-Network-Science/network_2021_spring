# %%
import importlib as imp
import Mark_hazi3 as h
imp.reload(h)
# Out:
# <module 'Mark_hazi3' from 'C:\\Users\\Lenovo ThinkPad T450\\Desktop\\Network Science\\Mark_hazi3.py'>

# %% [markdown]
# Ezt a hálózatot válaszotttam: https://snap.stanford.edu/data/ca-GrQc.html

# %% [markdown]
# Az átmérőt és a legrövidebb utat még nem tudtam kiszámolni, mert több komponensből áll a hálózat és ahogy utána olvastam,
# külön kell majd őket kezelni, vagy effektív átmérőt számolni.

# %%
h.generate_hazi3()
# Out:
# Csomópontok száma: 5242
# Klaszterezettségi együttható: 0.529635811052136
# Átlagos fokszám: 5.528424265547501
# A gráf nem kapcsolódik össze teljesen, vannak izolált pontok, vagyis több komponensből áll. Ezért végtelen az átmérője és nem talál átlagos legrövidebb utat.

# %% [markdown]
# A fokszámeloszlás Pareto eloszlásra hasonlít.

# %%
h.halozat()

# %% [markdown]
# A hálózat ábrázolásába még bele kell tanulnom, egyelőre nem szép, cserébe nem is informatív.
