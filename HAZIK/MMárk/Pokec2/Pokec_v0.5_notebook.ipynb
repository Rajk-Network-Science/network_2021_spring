# %%
import csv
import pandas as pd
import networkx as nx
import numpy as np
import re
import matplotlib.pyplot as plt
from nxviz import ArcPlot

# %%
COLORNODE = '#40a6d1'
COLOREDGE = '#5be732'

# %%
header = [
    "user_id",
    "public",
    "completion_percentage",
    "gender",
    "region",
    "last_login",
    "registration",
    "AGE",
    "body",
    "I_am_working_in_field",
    "spoken_languages",
    "hobbies",
    "I_most_enjoy_good_food",
    "pets",
    "body_type",
    "my_eyesight",
    "eye_color",
    "hair_color",
    "hair_type",
    "completed_level_of_education",
    "favourite_color",
    "relation_to_smoking",
    "relation_to_alcohol",
    "sign_in_zodiac",
    "on_pokec_i_am_looking_for",
    "love_is_for_me",
    "relation_to_casual_sex",
    "my_partner_should_be",
    "marital_status",
    "children",
    "relation_to_children",
    "I_like_movies",
    "I_like_watching_movie",
    "I_like_music",
    "I_mostly_like_listening_to_music",
    "the_idea_of_good_evening",
    "I_like_specialties_from_kitchen",
    "fun",
    "I_am_going_to_concerts",
    "my_active_sports",
    "my_passive_sports",
    "profession",
    "I_like_books",
    "life_style",
    "music",
    "cars",
    "politics",
    "relationships",
    "art_culture",
    "hobbies_interests",
    "science_technologies",
    "computers_internet",
    "education",
    "sport",
    "movies",
    "travelling",
    "health",
    "companies_brands",
    "more",
    "more"]

# %%
import importlib as imp
import Pokec_v05 as h
imp.reload(h)
# Out:
# <module 'Pokec_v05' from 'C:\\Users\\Lenovo ThinkPad T450\\Desktop\\Network Science\\Pokec\\Pokec_v05.py'>

# %%
h.nodes()
# Out:
#          user_id  public  completion_percentage  gender  \
# 782          821       0                     16     1.0
# 2138        1945       1                     76     1.0
# 2285        2247       1                     21     0.0
# 2461        2375       1                     72     1.0
# 3524        3476       0                     52     0.0
# ...          ...     ...                    ...     ...
# 1632386  1632388       1                     26     0.0
# 1632494  1632496       0                     12     0.0
# 1632496  1632498       1                     12     0.0
# 1632532  1632534       1                     36     0.0
# 1632614  1632616       1                     16     1.0
#
#                                 region             last_login  \
# 782      trenciansky kraj, partizanske  2012-05-07 14:35:00.0
# 2138     trenciansky kraj, partizanske  2012-05-25 19:51:00.0
# 2285     trenciansky kraj, partizanske  2012-05-18 20:45:00.0
# ...

# %%
h.nodes_clearing(h.nodes())
# Out:
#          user_id  gender   age
# 782          821     1.0  25.0
# 2138        1945     1.0  23.0
# 2285        2247     0.0  20.0
# 2461        2375     1.0  22.0
# 3524        3476     0.0   0.0
# ...          ...     ...   ...
# 1632386  1632388     0.0  10.0
# 1632494  1632496     0.0  40.0
# 1632496  1632498     0.0  39.0
# 1632532  1632534     0.0   0.0
# 1632614  1632616     1.0   0.0
#
# [11942 rows x 3 columns]

# %%
h.select_edges(h.nodes())
# Out:
#           start      end
# 8650753  201433   854474
# 8650754  201433   426420
# 8650755  201433  1077156
# 8650756  201433   654226
# 8650757  201433   549772
# ...         ...      ...
# 8650744  201433   668825
# 8650748  201433   312805
# 8650749  201433   307847
# 8650750  201433   188238
# 8650751  201433   350227
#
# [122990 rows x 2 columns]

# %%
h.merge(h.nodes_clearing(h.nodes()), h.select_edges(h.nodes()))
# Out:
#           start      end  user_id1  gender1  age1  user_id2  gender2  age2  \
# 0        201433   854474    201433      0.0   0.0    854474      0.0   0.0
# 1        301898   854474    301898      1.0   0.0    854474      0.0   0.0
# 2         37396   854474     37396      0.0   0.0    854474      0.0   0.0
# 3        642596   854474    642596      1.0   0.0    854474      0.0   0.0
# 4        648838   854474    648838      1.0   0.0    854474      0.0   0.0
# ...         ...      ...       ...      ...   ...       ...      ...   ...
# 122985    55824   641566     55824      1.0   0.0    641566      0.0   0.0
# 122986   647891  1443344    647891      1.0   0.0   1443344      1.0   0.0
# 122987   647891   491416    647891      1.0   0.0    491416      1.0   0.0
# 122988   647891   991071    647891      1.0   0.0    991071      1.0  28.0
# 122989  1229436  1346037   1229436      1.0  16.0   1346037      0.0  15.0
#
#                   edgelist
# 0         [201433, 854474]
# ...

# %%
h.network_generation(h.nodes_clearing(h.nodes()), h.merge(h.nodes_clearing(h.nodes()), h.select_edges(h.nodes())) )

# %%
h.elemzes(h.merge(h.nodes_clearing(h.nodes()), h.select_edges(h.nodes())))
# Out:
# Az egész mintán nézve:
# False    5206
# True     4354
# Name: is_correct, dtype: int64
# Nincs megadva kor:
# False    1646
# True     1250
# Name: is_correct, dtype: int64
# 20 év alatt:
# False    1379
# True      964
# Name: is_correct, dtype: int64
# 20 és 30 év között:
# False    1471
# True     1380
# Name: is_correct, dtype: int64
# 30 és 40 év között:
# True     538
# False    521
# Name: is_correct, dtype: int64
# 40 és 50 év között:
# True     167
# False    144
# Name: is_correct, dtype: int64
# 50 és 60 év között:
# True     46
# False    35
# Name: is_correct, dtype: int64
# 60 év felett:
# False    10
# True      9
# Name: is_correct, dtype: int64

# %%
h.by_age(h.merge(h.nodes_clearing(h.nodes()), h.select_edges(h.nodes())))
