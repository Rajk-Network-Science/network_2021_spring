# %%
import matplotlib
import networkx as nx
import csv
import matplotlib.pyplot as plt
import statistics
import numpy as np
import pandas as pd
import random

# %%
COLORNODE = '#40a6d1'
COLOREDGE = '#5be732'

# %%
import importlib as imp
import Mark_hazi4 as h
imp.reload(h)
# Out:
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.02697684185188071
# Átlagos fokszám: 5.905882352941177
# Átmérő: 6
# Átlagos legrövidebb út: 3.5605476341665225
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.007189887460061301
# Átlagos fokszám: 5.758823529411765
# Átmérő: 7
# Átlagos legrövidebb út: 4.034066462698917
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.09004063671195957
# Átlagos fokszám: 6.254901960784314
# Átmérő: 6
# Átlagos legrövidebb út: 3.175510400431026
# <module 'Mark_hazi4' from 'C:\\Users\\Lenovo ThinkPad T450\\Desktop\\Network Science\\Mark_hazi4.py'>

# %%
h.erdos_renyi()

# %%
h.link_selection()
# Out:
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.028455087553854605
# Átlagos fokszám: 5.91764705882353
# A gráf nem kapcsolódik össze teljesen, vannak izolált pontok, vagyis több komponensből áll. Ezért végtelen az átmérője és nem talál átlagos legrövidebb utat.

# %%
h.copy_modell()
# Out:
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.008631206888251102
# Átlagos fokszám: 5.756862745098039
# Átmérő: 7
# Átlagos legrövidebb út: 4.001010217629741

# %%
h.B_M()
# Out:
# Csúcsok száma: 1020
# Klaszterezettségi együttható: 0.10196481815316329
# Átlagos fokszám: 6.254901960784314
# Átmérő: 5
# Átlagos legrövidebb út: 3.1566530046758645
