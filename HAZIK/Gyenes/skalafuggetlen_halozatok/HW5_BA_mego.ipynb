# %%
import HW5_BA as h
import importlib as imp
imp.reload(h)
from HW5_BA import BA_rand_prob_node
from HW5_BA import add_edge
from HW5_BA import megoldas
from HW5_BA import graf_abra
from HW5_BA import k_distrib
import networkx as nx

# %%
kezdeti_csomopontok=20 # Kezdeti csomópontok száma
N=1000 # Összes csompópont
G=nx.erdos_renyi_graph(kezdeti_csomopontok,0.2, seed=10) # Erdős-Rényi gráfból indulok
m_parameter=3
count = 0
uj_csomopont = kezdeti_csomopontok

# %%
np.random.seed(seed=10)
megoldas(G, N, kezdeti_csomopontok, m_parameter, count, uj_csomopont)

# %% [markdown]
# # Gráf

# %%
graf_abra(G)

# %% [markdown]
# # Fokszámeloszlás

# %%
k_distrib(G, fit_line=True, expct_lo=1, expct_hi=100, expct_const=9)
