# %%
# %run gyenes_vizu.py

# %% [markdown]
# # DATA

# %%
node_features,edge_features=generate_data(data,data2)

# %%
edge_features
# Out:
#                    origin                     destination  migration  \
# 0             Afghanistan                       Australia    17199.0
# 1                 Albania                       Australia      587.0
# 2               Argentina                       Australia     1138.0
# 3                 Austria                       Australia    -3604.0
# 4              Bangladesh                       Australia    13142.0
# ...                   ...                             ...        ...
# 3564         South Africa                         Lesotho     1620.0
# 3565             Thailand                        Cambodia      319.0
# 3566              Vietnam                        Cambodia      376.0
# 3567  Trinidad and Tobago                         Grenada        0.0
# 3568  Trinidad and Tobago  St. Vincent and the Grenadines        0.0
#
#       display_edgesize
# 0             4.754473
# 1             0.162270
# 2             0.314587
# 3            -0.996286
# ...

# %%
node_features
# Out:
#                     stock_migration  display_nodesize
# Origin
# Afghanistan               5041262.0        120.361113
# Albania                   1182983.0        109.055751
# Algeria                   1809991.0        112.372471
# Andorra                      6147.0         68.035069
# Angola                     649841.0        104.383713
# ...                             ...               ...
# Vietnam                   2683739.0        115.444357
# West Bank and Gaza        3846187.0        118.250943
# Yemen, Rep.               1206052.0        109.206370
# Zambia                     266651.0         97.436589
# Zimbabwe                   727171.0        105.260569
#
# [201 rows x 2 columns]

# %% [markdown]
# # Graph

# %%
mignet=graf_vizu(edge_features,node_features, logarithm=True)
mignet.show("mig.html")
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="mig.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
